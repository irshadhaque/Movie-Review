# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in d:\movies\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in d:\movies\lib\site-packages (from beautifulsoup4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # pushpa 2

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt16539454/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('movie_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to movie_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to movie_reviews.csv

# %% [markdown]
# # stree 2

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt27510174/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('stree2_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to stree2_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to stree2_reviews.csv

# %% [markdown]
# # jawan

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt15354916/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('jawan_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to jawan_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to jawan_reviews.csv

# %% [markdown]
# # bb3

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt26932223/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('bb3_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to bb3_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to bb3_reviews.csv

# %% [markdown]
# # singham 3

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt11976134/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('singham3_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to singham3_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to singham3_reviews.csv

# %%
salaar

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt13927994/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('salaar_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to salaar_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to salaar_reviews.csv

# %%
animal

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt13751694/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('animal_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to animal_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to animal_reviews.csv

# %%
maharaja

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt26548265/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('maharaja_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to maharaja_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to maharaja_reviews.csv

# %%
luckybaskhar

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt27540542/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('luckybaskhar_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to luckybaskhar_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")

# %%
fighter

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt13818368/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('fighter_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to fighter_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to fighter_reviews.csv

# %%
jailer

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt11663228/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('jailer_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to jailer_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to jailer_reviews.csv

# %%
deadpool&wwolverine

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt6263850/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('deadpool&wwolverine_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to deadpool&wwolverine_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to deadpool&wwolverine_reviews.csv

# %%
dunki

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt15428134/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('dunki_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to dunki_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to dunki_reviews.csv

# %%
sambahadur

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt10786774/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('sambahadur_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to sambahadur_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to sambahadur_reviews.csv

# %%
maidaan

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt10869778/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('maidaan_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to maidaan_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to maidaan_reviews.csv

# %%
shaitaan

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt27744786/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('shaitaan_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to shaitaan_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to shaitaan_reviews.csv

# %%
srikanth

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt23790740/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('srikanth_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to srikanth_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to srikanth_reviews.csv

# %%
madgaonexpress

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt26745657/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('madgaonexpress_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to madgaonexpress_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to madgaonexpress_reviews.csv

# %%
chanduchampion

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt27470893/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('chanduchampion_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to chanduchampion_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to chanduchampion_reviews.csv

# %%
kalhonaaho

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt0347304/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('kalhonaaho_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to kalhonaaho_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to kalhonaaho_reviews.csv

# %%
mainhoonna

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt0347473/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('mainhoonna_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to mainhoonna_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to mainhoonna_reviews.csv

# %%
fan

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt3495026/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('fan_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to fan_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to fan_reviews.csv

# %%
raees

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt3405236/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('raees_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to raees_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to raees_reviews.csv

# %%
don

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt0461936/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('don_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to don_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to don_reviews.csv

# %%
swades

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the IMDb movie reviews page
url = 'https://www.imdb.com/title/tt0367110/reviews/?ref_=tt_urv_sm'

# Add headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Send HTTP request to fetch the page
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all review divs
    reviews = soup.find_all('div', class_='ipc-html-content-inner-div')

    # Open CSV file to save the reviews
    with open('swades_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review'])  # Write header row
       
        # Loop through each review and extract the text
        for review in reviews:
            review_text = review.get_text(strip=True)
            if review_text:  # Only write non-empty reviews
                writer.writerow([review_text])

    print("Reviews have been saved to swades_reviews.csv")
else:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
# Out:
# Reviews have been saved to swades_reviews.csv
